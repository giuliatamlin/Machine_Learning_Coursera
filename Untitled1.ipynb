# %%
import numpy as np

# %%
import matplotlib.pylab as plt

# %%
# %matplotlib inline

# %%
x = np.linspace(0, 100, 1000)

# %%
y = np.sin(x)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x, y)

# %% [markdown]
# The above is a plot of $\sin(x)$ `xxx`
#
# *   This
# *   Ist
#     *  a
#     * sublist
